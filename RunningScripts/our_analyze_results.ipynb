# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
from read_wandb import wandb_results
api = wandb_results("206713612", wandb_username="maayan-aytek1")

BASE_METRIC = "accuracy_per_mean_user_and_bot"

# %%
def result_metric(sweeps, group_name, drop_list=[0], drop_HPT=False, metric=BASE_METRIC, epoch="best", dummy_group=False, model=False):
    df = api.get_sweeps_results(sweeps, metric=metric) 
    config_cols = [c for c in df.columns if "config_" in c and c!="config_wandb_run_id" and c!="config_online_simulation_size"]
    HPT_cols = [col for col in config_cols if df[col].nunique() > 1]
    if drop_HPT:
        df=df.drop([c for c in HPT_cols if not c in ["config_LLM_SIM_SIZE", "config_seed"]], axis=1)
        HPT_cols = ["config_LLM_SIM_SIZE", "config_seed"]  
    numeric_cols = df.select_dtypes(include='number').columns.tolist()
    if model: 
        df['config_rt_model_file_name'] = df['config_rt_model_file_name'].apply(lambda x: x.split('_seed')[0])
    if not dummy_group:
        grouped = df.groupby([c for c in HPT_cols if c != "config_seed"])
    else:
        df['dummy_group'] = 'New LLM'
        
        grouped = df.groupby('dummy_group')
    
    mean_df = grouped[numeric_cols].mean()
    std_df = grouped[numeric_cols].std()
    
    if epoch=="best":
        best_col = mean_df[[c for c in mean_df.columns if (metric in c and metric[-4:] == c.split("_epoch")[0][-4:])]].idxmax(axis=1)
    else:
        best_col = mean_df[[c for c in mean_df.columns if f"{metric}_epoch{epoch}" in c]].idxmax(axis=1)
    
    result = grouped.apply(lambda x: x[best_col.loc[x.name]].values)
    means = grouped.apply(lambda x: x[best_col.loc[x.name]].mean())
    stds = grouped.apply(lambda x: x[best_col.loc[x.name]].std())
    
    df_cols = {'mean': means, 'std': stds, 'values': result.values}
    
    if epoch == "best":
        df_cols['epoch'] = best_col.apply(lambda x: int(x.split("epoch")[1]) if "epoch" in x else "last")
    
    df_cols['CI'] = result.apply(lambda x: bootstrap_ci(x))
    summary_df = pd.DataFrame(df_cols, index=best_col.index)
    
    for d in drop_list:
        if d in summary_df.index:
            summary_df=summary_df.drop(d)

    if len(summary_df.index.names) == 1:
        return summary_df.rename_axis(group_name)
    else:
        return summary_df

def bootstrap_ci(data, n_bootstrap=1000, ci=0.95):
    bootstrapped_means = []
    for _ in range(n_bootstrap):
        sample = np.random.choice(data, size=len(data), replace=True)
        bootstrapped_means.append(np.mean(sample))
    lower_bound = np.percentile(bootstrapped_means, (1 - ci) / 2 * 100)
    upper_bound = np.percentile(bootstrapped_means, (1 + ci) / 2 * 100)
    return lower_bound, upper_bound

# %% [markdown]
# # For HyperParameterTuning

# %% [markdown]
# For every configuration that you test in the sweep, you will receive in the table the average, standard deviation, all the values obtained for the different seed values, and also the confidence interval within which the result is located at a confidence level of 95%.
#
# When epoch="best" is defined, you can check in which epoch the best result is obtained. If epoch=5 is defined, you will receive the result obtained for epoch number 5.
#
# You can test multiple sweeps simultaneously by entering them into the list found in the first element of the function result_metric.

# %% [markdown]
# ### Baseline

# %%
sweep_results = result_metric(["nh9eyaq1"], "LLMs", drop_HPT=False, epoch='best', dummy_group=True)
sweep_results
# Out:
# Total number of sweeps: 1
# Download sweep_id='nh9eyaq1' data...
#             mean       std                                             values  \
# LLMs
# New LLM  0.83619  0.001682  [0.8371521808705251, 0.834866139441589, 0.8339...
#
#          epoch                                        CI
# LLMs
# New LLM     14  (0.8347828277726637, 0.8374292824620626)

# %% [markdown]
# ### Random

# %%
sweep_results = result_metric(["gihrejb0"], "LLMs", drop_HPT=False, epoch='best')
sweep_results
# Out:
# Total number of sweeps: 1
# Download sweep_id='gihrejb0' data...
#              mean       std  \
# LLMs
# normal   0.839446  0.002792
# uniform  0.838915  0.001628
#
#                                                     values  epoch  \
# LLMs
# normal   [0.8417926790544936, 0.841346422342924, 0.8374...     22
# uniform  [0.8413149271737511, 0.8377004597636084, 0.839...     16
#
#                                                CI
# LLMs
# normal   (0.8370903771143301, 0.8414253805629688)
# uniform  (0.8377142146690236, 0.8401623859949275)

# %% [markdown]
# ### Models

# %%
sweep_results = result_metric(["42wibgw1"], "LLMs", drop_HPT=False, epoch='best', dummy_group=False, model=True)
sweep_results
# Out:
# Total number of sweeps: 1
# Download sweep_id='42wibgw1' data...
#                                                                                                                                                    mean  \
# config_rt_model_file_name                          config_rt_model_class_weight config_rt_model_top_features config_rt_model_min_samples_leaf
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           20                           100                               0.836768
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           all                          100                               0.836900
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     20                           100                               0.837315
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     all                          100                               0.837462
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           20                           20                                0.836669
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           all                          20                                0.837695
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     20                           20                                0.836614
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     all                          20                                0.836802
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           20                           50                                0.837531
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           all                          50                                0.838501
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     20                           50                                0.836985
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     all                          50                                0.837996
#
#                                                                                                                                                     std  \
# config_rt_model_file_name                          config_rt_model_class_weight config_rt_model_top_features config_rt_model_min_samples_leaf
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           20                           100                               0.001404
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           all                          100                               0.000252
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     20                           100                               0.001356
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     all                          100                               0.002099
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           20                           20                                0.001892
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           all                          20                                0.001677
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     20                           20                                0.001761
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     all                          20                                0.001410
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           20                           50                                0.002032
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           all                          50                                0.000999
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     20                           50                                0.002070
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     all                          50                                0.001321
#
#                                                                                                                                                                                           values  \
# config_rt_model_file_name                          config_rt_model_class_weight config_rt_model_top_features config_rt_model_min_samples_leaf
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           20                           100                               [0.8351968767317809, 0.8379012449859079, 0.837...
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           all                          100                               [0.8371155752297419, 0.8366225382946252, 0.836...
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     20                           100                               [0.8385974426912752, 0.8374519736681949, 0.835...
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     all                          100                               [0.8398647309850867, 0.835986445817165, 0.8365...
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           20                           20                                [0.8379861002281137, 0.834501391657148, 0.8375...
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           all                          20                                [0.8377945331370256, 0.8359706140758668, 0.839...
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     20                           20                                [0.8356686748178921, 0.8355273771061232, 0.838...
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     all                          20                                [0.8379406353880007, 0.8352242637813103, 0.837...
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           20                           50                                [0.8383367194971337, 0.8352194818445661, 0.839...
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           all                          50                                [0.8373830504895878, 0.8388137564932842, 0.839...
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     20                           50                                [0.8387565355838527, 0.8374894392974622, 0.834...
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     all                          50                                [0.8379193280485923, 0.8393536954847494, 0.836...
#
#                                                                                                                                                epoch  \
# config_rt_model_file_name                          config_rt_model_class_weight config_rt_model_top_features config_rt_model_min_samples_leaf
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           20                           100                                  21
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           all                          100                                   9
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     20                           100                                  18
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     all                          100                                  18
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           20                           20                                   12
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           all                          20                                   11
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     20                           20                                   17
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     all                          20                                   15
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           20                           50                                   13
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           all                          50                                    9
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     20                           50                                   18
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     all                          50                                   18
#
#                                                                                                                                                                                      CI
# config_rt_model_file_name                          config_rt_model_class_weight config_rt_model_top_features config_rt_model_min_samples_leaf
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           20                           100                               (0.8351968767317809, 0.8379012449859079)
# min_samples_leaf_100_class_weight_balanced_subs... balanced_subsample           all                          100                               (0.8366225382946252, 0.8371155752297419)
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     20                           100                               (0.8358950308736369, 0.8385974426912752)
# min_samples_leaf_100_class_weight_balanced_top_... balanced                     all                          100                                (0.835986445817165, 0.8398647309850867)
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           20                           20                                 (0.834501391657148, 0.8379861002281137)
# min_samples_leaf_20_class_weight_balanced_subsa... balanced_subsample           all                          20                                (0.8359706140758668, 0.8393197174370671)
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     20                           20                                (0.8355273771061232, 0.8386460324534374)
# min_samples_leaf_20_class_weight_balanced_top_f... balanced                     all                          20                                (0.8352242637813103, 0.8379406353880007)
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           20                           50                                (0.8352194818445661, 0.8390366751829358)
# min_samples_leaf_50_class_weight_balanced_subsa... balanced_subsample           all                          50                                (0.8378480299407891, 0.8393070493026439)
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     20                           50                                (0.8347092068147258, 0.8387565355838525)
# min_samples_leaf_50_class_weight_balanced_top_f... balanced                     all                          50                                (0.8367151589202745, 0.8393536954847494)

# %% [markdown]
# ### Heuristic

# %%
sweep_results = result_metric(["rr4bf5bj"], "LLMs", drop_HPT=False, epoch='best', dummy_group=False)
sweep_results.reset_index()
# Out:
# Total number of sweeps: 1
# Download sweep_id='rr4bf5bj' data...
#     config_rt_user_noise_std config_rt_neutral_sampling  \
# 0                        200                       1000
# 1                        200                       1000
# 2                        200                        800
# 3                        200                        800
# 4                        200                     normal
# 5                        200                     normal
# 6                        300                       1000
# 7                        300                       1000
# 8                        300                        800
# 9                        300                        800
# 10                       300                     normal
# 11                       300                     normal
# 12                       500                       1000
# 13                       500                       1000
# 14                       500                        800
# 15                       500                        800
# 16                       500                     normal
# 17                       500                     normal
#
#    config_rt_frustration_std_method      mean       std  \
# 0                                 +  0.836979  0.001992
# 1                                 /  0.837570  0.002598
# 2                                 +  0.837341  0.002995
# 3                                 /  0.837163  0.002275
# 4                                 +  0.837345  0.001237
# 5                                 /  0.837635  0.002379
# 6                                 +  0.838036  0.002364
# 7                                 /  0.836368  0.000789
# 8                                 +  0.837205  0.001097
# 9                                 /  0.836295  0.001916
# 10                                +  0.836651  0.001602
# 11                                /  0.837308  0.004430
# 12                                +  0.835057  0.001580
# 13                                /  0.835675  0.002599
# 14                                +  0.838632  0.001199
# 15                                /  0.835626  0.002159
# 16                                +  0.837084  0.002260
# 17                                /  0.836505  0.002027
#
#                                                values epoch  \
# 0   [0.8400159701451503, 0.8374672073500151, 0.834...    20
# 1   [0.8393964648476003, 0.8355232446906189, 0.839...  last
# 2   [0.8378782271688218, 0.8351722705271559, 0.840...    14
# 3   [0.8388582202235954, 0.8338600988903725, 0.836...    19
# 4   [0.8365394680610218, 0.8384429625645824, 0.836...    12
# 5   [0.839637143670511, 0.8401320919190824, 0.8344...    11
# 6   [0.8414243308476722, 0.839321243925161, 0.8364...    14
# 7   [0.8366641666218375, 0.8354961955228851, 0.837...    14
# 8   [0.8390263045485709, 0.8369912642463646, 0.837...    18
# 9   [0.8346060943480512, 0.8390550693024155, 0.834...     8
# 10  [0.8343192147299392, 0.8387011177939945, 0.836...    13
# 11  [0.8394666373737028, 0.8439833540410289, 0.833...    15
# 12  [0.8367845534149819, 0.8367645085682821, 0.833...    12
# 13  [0.8343932578091682, 0.8395818907920679, 0.836...     9
# 14  [0.8401141721684653, 0.8393247337820757, 0.838...    19
# 15  [0.8380151551561452, 0.8321350136715292, 0.835...    10
# 16  [0.8352335285423785, 0.8394964641243421, 0.839...    15
# 17  [0.8382175515339503, 0.8373418999782305, 0.836...    13
#
#                                           CI
# 0    (0.835508510753624, 0.8386065825734462)
# 1   (0.8354718042123036, 0.8394873807381027)
# 2   (0.8350102656603005, 0.8396724216486516)
# 3   (0.8353541311863246, 0.8388281644230622)
# 4   (0.8364254228451934, 0.8383448839529024)
# 5   (0.8357560426088992, 0.8394628844213561)
# 6    (0.8363162179299343, 0.839851659987934)
# 7   (0.8357412774935529, 0.8369838304369315)
# 8   (0.8365180792493341, 0.8381647341407689)
# 9   (0.8348687521753421, 0.8378505506671526)
# 10   (0.8352438615294936, 0.837825084816045)
# 11  (0.8340846981070829, 0.8409320180439511)
# 12  (0.8338480950826745, 0.8362663829140391)
# 13   (0.8338540472399568, 0.837549373786009)
# 14  (0.8376986890356237, 0.8395451581487936)
# 15  (0.8337110845899056, 0.8371417514538398)
# 16  (0.8353007647808017, 0.8388677740384496)
# 17  (0.8348013645973431, 0.8377456476940689)

# %%
sweep_results = result_metric(["nbpew7o7"], "LLMs", drop_HPT=False, epoch='best')
sweep_results.reset_index()
# Out:
# Total number of sweeps: 1
# Download sweep_id='nbpew7o7' data...
#     config_rt_w_word_count  config_rt_user_noise_std  \
# 0                      100                       300
# 1                      100                       300
# 2                      100                       300
# 3                      100                       300
# 4                      100                       500
# 5                      100                       500
# 6                      100                       500
# 7                      100                       500
# 8                      125                       300
# 9                      125                       300
# 10                     125                       300
# 11                     125                       300
# 12                     125                       500
# 13                     125                       500
# 14                     125                       500
# 15                     125                       500
# 16                     150                       300
# 17                     150                       300
# 18                     150                       300
# 19                     150                       300
# 20                     150                       500
# 21                     150                       500
# 22                     150                       500
# 23                     150                       500
#
#    config_rt_neutral_sampling config_rt_frustration_std_method      mean  \
# 0                         800                                +  0.837840
# 1                         800                                /  0.837519
# 2                      normal                                +  0.835220
# 3                      normal                                /  0.836491
# 4                         800                                +  0.837148
# 5                         800                                /  0.836417
# 6                      normal                                +  0.838096
# 7                      normal                                /  0.837569
# 8                         800                                +  0.837479
# 9                         800                                /  0.837627
# 10                     normal                                +  0.837244
# 11                     normal                                /  0.837045
# 12                        800                                +  0.838223
# 13                        800                                /  0.836556
# 14                     normal                                +  0.836346
# 15                     normal                                /  0.834667
# 16                        800                                +  0.837429
# 17                        800                                /  0.837763
# 18                     normal                                +  0.837723
# 19                     normal                                /  0.838009
# 20                        800                                +  0.837408
# 21                        800                                /  0.837015
# 22                     normal                                +  0.837065
# 23                     normal                                /  0.837254
#
#          std                                             values  epoch  \
# 0   0.001723  [0.836172188969917, 0.836579488401076, 0.84015...     22
# 1   0.002820  [0.839166817432858, 0.8329689571112405, 0.8395...     11
# 2   0.003414  [0.8376617060210955, 0.8392727205382021, 0.834...     11
# 3   0.002456  [0.832658002629589, 0.8367654591560809, 0.8391...     21
# 4   0.001692  [0.8366598385392795, 0.8380214936007504, 0.834...     16
# 5   0.002582  [0.834134035364125, 0.8334936388840091, 0.8375...      9
# 6   0.001728  [0.8390777263369343, 0.8363773095737908, 0.836...     13
# 7   0.001642  [0.8364708377864782, 0.8359907639124565, 0.837...      9
# 8   0.001908  [0.8364306485204729, 0.8349607179169425, 0.838...      8
# 9   0.001108  [0.8357700301111456, 0.8376176596470892, 0.837...     10
# 10  0.001913  [0.8397194048383075, 0.834928156040761, 0.8384...     11
# 11  0.001511  [0.8357743356526374, 0.8383145175829723, 0.838...     16
# 12  0.001964  [0.8409389007449737, 0.8386020592885226, 0.838...     11
# 13  0.001490  [0.8347285406780047, 0.8371314095451575, 0.838...     21
# 14  0.002270  [0.8354628722572264, 0.8401010156376092, 0.836...     13
# 15  0.002586  [0.8374413321526983, 0.8316936287200133, 0.834...      7
# 16  0.002270  [0.8348665114051048, 0.8410353039045291, 0.836...     12
# 17  0.002058  [0.8380442298043497, 0.8384436679893389, 0.839...     19
# 18  0.001442  [0.8361332841302294, 0.8369681596725786, 0.837...     12
# 19  0.002252  [0.8361870629960755, 0.8418719106956647, 0.836...      9
# 20  0.002367  [0.8350726934143243, 0.8396808656607951, 0.835...      9
# 21  0.002401  [0.8379098193227573, 0.8386763980918258, 0.838...     13
# 22  0.002838  [0.835307651987045, 0.8367765454202643, 0.8387...      8
# 23  0.002175  [0.8398129435060909, 0.8362762358015678, 0.838...     14
#
#                                           CI
# 0   (0.8365319132452115, 0.8391555037614566)
# 1   (0.8350123118189254, 0.8394238874436792)
# 2   (0.8326762423901691, 0.8376561332746605)
# 3   (0.8345352170377369, 0.8382555474966049)
# 4    (0.835887816148858, 0.8383356143874625)
# 5   (0.8344918316847758, 0.8387329609869948)
# 6   (0.8367775397945628, 0.8394134796978285)
# 7   (0.8364583660782661, 0.8391581024419456)
# 8    (0.835887495920384, 0.8388797608196771)
# 9   (0.8366965060274089, 0.8383359047075553)
# 10  (0.8357845246423559, 0.8387034631157433)
# 11  (0.8358537857599291, 0.8382357772836384)
# 12  (0.8367645082880946, 0.8400041641623932)
# 13  (0.8354286006926198, 0.8378205488205618)
# 14  (0.8348360263124516, 0.8383204709386594)
# 15  (0.8326139547128524, 0.8366252643235118)
# 16  (0.8358724966830422, 0.8394690311651944)
# 17   (0.8359203997609981, 0.838933430264205)
# 18    (0.836672812414359, 0.838828022584421)
# 19  (0.8366539029670716, 0.8400118755308791)
# 20  (0.8355273822086475, 0.8393007967817239)
# 21  (0.8349338506903367, 0.8386342782812687)
# 22  (0.8349279968733093, 0.8392026858651189)
# 23  (0.8356270770775553, 0.8388810669731243)
